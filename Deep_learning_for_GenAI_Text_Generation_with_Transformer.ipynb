# %% [markdown]
# <a href="https://colab.research.google.com/github/Chan3377/Deep-learning-for-GenAI-Text-Generation-with-Transformer-Model/blob/main/Deep_learning_for_GenAI_Text_Generation_with_Transformer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Generative deep learning

# %% [markdown]
# ## Text generation

# %% [markdown]
# ### How do you generate sequence data?

# %% [markdown]
# - The universal way to generate sequence data in deep learning is to ***train a model*** (usually a Transformer or an RNN) ***to predict the next token or next few tokens in a sequence, using the previous tokens as input***.
#     - For instance, given the input “the cat is on the,” the model is trained to **predict the target “mat,”** the next word
# - As usual when **working with text data**, tokens are typically words or characters, and any **network that can model the probability of the next token given the previous ones** is called a ***language model***.

# %% [markdown]
# ### The importance of the sampling strategy

# %% [markdown]
# - **Sampling strategy** is the way you ***choose the next token*** which is crucially important for generating text.

# %% [markdown]
# - ***When sampling from generative models***, it’s always good to ***explore different amounts of randomness in the generation process***. But **how can we explore the amounts of randomness?** Introducing ***softmax temperature*** parameter
#     - **Softmax temperature ****is ******a parameter used to ***control the amount of stochasticity in the sampling process (Randomness)***, which ***characterizes the entropy of the probability distribution*** used for sampling: it ***characterizes how surprising or predictable the choice of the next word will be***.

# %% [markdown]
# **Reweighting a probability distribution to a different temperature**

# %%
import numpy as np
# original_distribution is a 1D NumPy array of probability values that must sum to 1. temperature is a factor
# quantifying the entropy of the output distribution
def reweight_distribution(original_distribution, temperature=0.5):
    distribution = np.log(original_distribution) / temperature
    distribution = np.exp(distribution)
    return distribution / np.sum(distribution)
# Returns a reweighted version of the original distribution.
# The sum of the distribution may no longer be 1, so you divide it by its sum to obtain the new distribution

# %% [markdown]
# ### Implementing text generation with Keras

# %% [markdown]
# #### Preparing the data

# %% [markdown]
# **Downloading and uncompressing the IMDB movie reviews dataset**

# %%
# !wget https://ai.stanford.edu/~amaas/data/sentiment/aclImdb_v1.tar.gz
# !tar -xf aclImdb_v1.tar.gz
# Out:
# --2024-01-14 05:10:56--  https://ai.stanford.edu/~amaas/data/sentiment/aclImdb_v1.tar.gz
# Resolving ai.stanford.edu (ai.stanford.edu)... 171.64.68.10
# Connecting to ai.stanford.edu (ai.stanford.edu)|171.64.68.10|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 84125825 (80M) [application/x-gzip]
# Saving to: ‘aclImdb_v1.tar.gz’
#
# aclImdb_v1.tar.gz   100%[===================>]  80.23M  49.9MB/s    in 1.6s
#
# 2024-01-14 05:10:58 (49.9 MB/s) - ‘aclImdb_v1.tar.gz’ saved [84125825/84125825]

# %% [markdown]
# **Creating a dataset from text files (one file = one sample)**

# %%
import tensorflow as tf
from tensorflow import keras
dataset = keras.utils.text_dataset_from_directory(
    directory="aclImdb", label_mode=None, batch_size=256)
# Strip the <br /> HTML tag that occurs in many of the reviews.
# This did not matter much for text classification, but we wouldn’t want to generate <br /> tags in this project
dataset = dataset.map(lambda x: tf.strings.regex_replace(x, "<br />", " "))
# Out:
# Found 100006 files belonging to 1 classes.

# %% [markdown]
# **Preparing a `TextVectorization` layer**

# %% [markdown]
# - Use a TextVectorization layer to compute the vocabulary we’ll be working with.
# - Will only use the first sequence_length words of each review:
# - TextVectorization layer will cut off anything beyond that when vectorizing a text

# %%
from tensorflow.keras.layers import TextVectorization

sequence_length = 100
# only consider the top 15,000 most common words
# anything else will be treated as the out-of-vocabulary token, "[UNK]"
vocab_size = 15000
# output_mode - return integer word index sequences
# output_sequence - will work with inputs and targets of length 100
# (but since we’ll offset the targets by 1, the model will actually see sequences of length 99).
text_vectorization = TextVectorization(
    max_tokens=vocab_size,
    output_mode="int",
    output_sequence_length=sequence_length,
)
text_vectorization.adapt(dataset)

# %% [markdown]
# **Setting up a language modeling dataset**

# %% [markdown]
# - Use the layer to create a language modeling dataset where input samples are vectorized texts, and corresponding targets are the same texts offset by one word.

# %%
def prepare_lm_dataset(text_batch):
    # Convert a batch of texts (strings) to a batch of integer sequences.
    vectorized_sequences = text_vectorization(text_batch)
    # Create inputs by cutting off the last word of the sequences.
    x = vectorized_sequences[:, :-1]
    # Create targets by offsetting the sequences by 1.
    y = vectorized_sequences[:, 1:]
    return x, y

lm_dataset = dataset.map(prepare_lm_dataset, num_parallel_calls=4)

# %% [markdown]
# #### A Transformer-based sequence-to-sequence model

# %% [markdown]
# - How transformer-based sequence-to- sequence model work?
#     - A sequence-to-sequence model is trained by feeding sequences of ***N words (indexed from 0 to N)*** into our model, and we’ll ***predict the sequence offset by one (from 1 to N+1).***
#     - We’ll use causal masking to make sure that, for any ***i***, the model will only be using words from ***0 to i*** in order to ***predict the word i + 1***.
#     - This means that the model is trained simultaneously to solve N mostly overlapping but different problems: ***predicting the next words given a sequence of 1 <= i <= N prior words***.
#     - ***At generation time***, even if you only ***prompt the model with a single word***, it will be able to ***give you a probability distribution for the next possible words.***

# %% [markdown]
# Reuse the building blocks: **PositionalEmbedding** and **TransformerDecoder**.

# %%
import tensorflow as tf
from tensorflow.keras import layers

class PositionalEmbedding(layers.Layer):
    def __init__(self, sequence_length, input_dim, output_dim, **kwargs):
        super().__init__(**kwargs)
        self.token_embeddings = layers.Embedding(
            input_dim=input_dim, output_dim=output_dim)
        self.position_embeddings = layers.Embedding(
            input_dim=sequence_length, output_dim=output_dim)
        self.sequence_length = sequence_length
        self.input_dim = input_dim
        self.output_dim = output_dim

    def call(self, inputs):
        length = tf.shape(inputs)[-1]
        positions = tf.range(start=0, limit=length, delta=1)
        embedded_tokens = self.token_embeddings(inputs)
        embedded_positions = self.position_embeddings(positions)
        return embedded_tokens + embedded_positions

    def compute_mask(self, inputs, mask=None):
        return tf.math.not_equal(inputs, 0)

    def get_config(self):
        config = super(PositionalEmbedding, self).get_config()
        config.update({
            "output_dim": self.output_dim,
            "sequence_length": self.sequence_length,
            "input_dim": self.input_dim,
        })
        return config


class TransformerDecoder(layers.Layer):
    def __init__(self, embed_dim, dense_dim, num_heads, **kwargs):
        super().__init__(**kwargs)
        self.embed_dim = embed_dim
        self.dense_dim = dense_dim
        self.num_heads = num_heads
        self.attention_1 = layers.MultiHeadAttention(
          num_heads=num_heads, key_dim=embed_dim)
        self.attention_2 = layers.MultiHeadAttention(
          num_heads=num_heads, key_dim=embed_dim)
        self.dense_proj = keras.Sequential(
            [layers.Dense(dense_dim, activation="relu"),
             layers.Dense(embed_dim),]
        )
        self.layernorm_1 = layers.LayerNormalization()
        self.layernorm_2 = layers.LayerNormalization()
        self.layernorm_3 = layers.LayerNormalization()
        self.supports_masking = True

    def get_config(self):
        config = super(TransformerDecoder, self).get_config()
        config.update({
            "embed_dim": self.embed_dim,
            "num_heads": self.num_heads,
            "dense_dim": self.dense_dim,
        })
        return config

    def get_causal_attention_mask(self, inputs):
        input_shape = tf.shape(inputs)
        batch_size, sequence_length = input_shape[0], input_shape[1]
        i = tf.range(sequence_length)[:, tf.newaxis]
        j = tf.range(sequence_length)
        mask = tf.cast(i >= j, dtype="int32")
        mask = tf.reshape(mask, (1, input_shape[1], input_shape[1]))
        mult = tf.concat(
            [tf.expand_dims(batch_size, -1),
             tf.constant([1, 1], dtype=tf.int32)], axis=0)
        return tf.tile(mask, mult)

    def call(self, inputs, encoder_outputs, mask=None):
        causal_mask = self.get_causal_attention_mask(inputs)
        if mask is not None:
            padding_mask = tf.cast(
                mask[:, tf.newaxis, :], dtype="int32")
            padding_mask = tf.minimum(padding_mask, causal_mask)
        else:
            padding_mask = mask
        attention_output_1 = self.attention_1(
            query=inputs,
            value=inputs,
            key=inputs,
            attention_mask=causal_mask)
        attention_output_1 = self.layernorm_1(inputs + attention_output_1)
        attention_output_2 = self.attention_2(
            query=attention_output_1,
            value=encoder_outputs,
            key=encoder_outputs,
            attention_mask=padding_mask,
        )
        attention_output_2 = self.layernorm_2(
            attention_output_1 + attention_output_2)
        proj_output = self.dense_proj(attention_output_2)
        return self.layernorm_3(attention_output_2 + proj_output)

# %% [markdown]
# **A simple Transformer-based language model**

# %%
from tensorflow.keras import layers
embed_dim = 256
latent_dim = 2048
num_heads = 2

inputs = keras.Input(shape=(None,), dtype="int64")
x = PositionalEmbedding(sequence_length, vocab_size, embed_dim)(inputs)
x = TransformerDecoder(embed_dim, latent_dim, num_heads)(x, x)
# Softmax over possible vocabulary words, computed for each output sequence timestep
outputs = layers.Dense(vocab_size, activation="softmax")(x)
model = keras.Model(inputs, outputs)
model.compile(loss="sparse_categorical_crossentropy", optimizer="rmsprop")

# %% [markdown]
# ### A text-generation callback with variable-temperature sampling

# %% [markdown]
# **The text-generation callback**

# %% [markdown]
# Use a callback to generate text using a range of different temperatures after every epoch.
#
# * This allows you to see how the generated text evolves as the model begins to converge,
# * as well as the impact of temperature in the sampling strategy.

# %% [markdown]
# ***Note***: Use [UNK] to catch an "out of vocabulary" index
# - When decoding a sequence of integers back into words, you’ll replace 1 with something like “[UNK]” (which you’d call an “OOV token”).
# - “Why use 1 and not 0?” you may ask. That’s because 0 is already taken. There are two special tokens that you will commonly use: ***the OOV token (index 1)***, and ***the mask token (index 0)***.
# - While the OOV token means “here was a word we did not recognize,” the mask token tells us “ignore me, I’m not a word.”
# - You’d use it in particular to pad sequence data: because data batches need to be contiguous, all sequences in a batch of sequence data must have the same length, so shorter sequences should be padded to the length of the longest sequence.

# %%
import numpy as np

# Dict that maps word indices back to strings, to be used for text decoding
tokens_index = dict(enumerate(text_vectorization.get_vocabulary()))

# Implements variable temperature sampling from a probability distribution
def sample_next(predictions, temperature=1.0):
    predictions = np.asarray(predictions).astype("float64")
    predictions = np.log(predictions) / temperature
    exp_preds = np.exp(predictions)
    predictions = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, predictions, 1)
    return np.argmax(probas)

class TextGenerator(keras.callbacks.Callback):
    # prompt - Prompt that we use to seed text generation
    # generate_length - How many words to generate
    # temperature - Range of temperatures to use for sampling
    def __init__(self,
                 prompt,
                 generate_length,
                 model_input_length,
                 temperatures=(1.,),
                 print_freq=1):
        self.prompt = prompt
        self.generate_length = generate_length
        self.model_input_length = model_input_length
        self.temperatures = temperatures
        self.print_freq = print_freq
        vectorized_prompt = text_vectorization([prompt])[0].numpy()
        self.prompt_length = np.nonzero(vectorized_prompt == 0)[0][0]

    def on_epoch_end(self, epoch, logs=None):
        if (epoch + 1) % self.print_freq != 0:
            return
        for temperature in self.temperatures:
            print("== Generating with temperature", temperature)
            # when generating text, we start from our prompt
            sentence = self.prompt
            for i in range(self.generate_length):
                # Feed the current sequence into model
                tokenized_sentence = text_vectorization([sentence])
                predictions = self.model(tokenized_sentence)
                # Retrieve the predictions for the last timestep, and use them to sample a new word
                next_token = sample_next(
                    predictions[0, self.prompt_length - 1 + i, :]
                )
                # Append the new word to the current sequence and repeat
                sampled_token = tokens_index[next_token]
                sentence += " " + sampled_token
            print(sentence)

prompt = "This movie"
text_gen_callback = TextGenerator(
    prompt,
    generate_length=50,
    model_input_length=sequence_length,
    # Use a diverse range of temperatures to sample text, to demonstrate the effect of temperature on text generation
    temperatures=(0.2, 0.5, 0.7, 1., 1.5))

# %% [markdown]
# **Fitting the language model**

# %%
model.fit(lm_dataset, epochs=200, callbacks=[text_gen_callback])
# Out:
# Epoch 1/200
# 391/391 [==============================] - ETA: 0s - loss: 5.9245== Generating with temperature 0.2
# This movie looks for anything to albeit sold and if youve got read it like most tango movie it the plot and a drew and you said her music needs to be the surprises and we they renamed which even known what can be only laugh and even get the directors were
# == Generating with temperature 0.5
# This movie does were much better plot thanks to say its a sweet here for it and that [UNK] movie seems true director [UNK] cary talky is a [UNK] to this is close film it can work more recommend this movie had great thing about drilling she was to do not a
# == Generating with temperature 0.7
# This movie is a really many important that i [UNK] comedies this you have never then there was put away from sex but mostly how bad spoke goes stay at the case of course exactly the movie to person walked the parents if they should say that the plot ever read the
# == Generating with temperature 1.0
# This movie bette fictional the movie is that is a big ourselves this is a million for like a few looking for the first type has been a great in money and big clarity element of the [UNK] [UNK] a decent characters that so i should ever played out and international film
# == Generating with temperature 1.5
# This movie is one of life i really first was slow so but the film i have ever gone to be bruce country to start to say sometimes flashy was not detail about this and the film was jesus what the idea what is in the usual remember the science work if
# 391/391 [==============================] - 165s 408ms/step - loss: 5.9245
# Epoch 2/200
# 391/391 [==============================] - ETA: 0s - loss: 5.4541== Generating with temperature 0.2
# This movie was absolutely no idea except seeing it was just different legend in the typical a lot of extreme cheap special purity it has few times reasonably better than scary not entirely lacking in all i wasnt ridiculous clever and shotgun and action scenes think [UNK] and rather than science which
# == Generating with temperature 0.5
# This movie may be considered much the worst fans ideals of the box commander will have been 6 at the worst actors bad can watch animation is if there are on top giallo both fair 1 pacinos [UNK] only second particular industry hysterics even dee parody but i saw carries movies so
# == Generating with temperature 0.7
# This movie was a movie the little too hard at all starring james [UNK] was very slow experience the good in it was disappointing although i was guy i had recently ben was questionable scott was so i wish the plot was a circus and not just run paul cars and [UNK]
# == Generating with temperature 1.0
# This movie had asian classic i have ever seen at my swift lift off the rings funnier than other bits i am still understand the theater throwback to rating of all any [UNK] and that if i thought again it was perhaps it basically shows points to young boy and over them
# == Generating with temperature 1.5
# This movie is and for my over the kind of being alive all i am filmed in complexity it was always like the the london frequently liked the ocean the acting was just was very flawed the movie for watching it seems there i would say enough to just perfect i finally
# 391/391 [==============================] - 167s 426ms/step - loss: 5.4541
# Epoch 3/200
# 391/391 [==============================] - ETA: 0s - loss: 5.3141== Generating with temperature 0.2
# This movie was a lot of jewel a lot i think it about it means of all the worst of like it was watching this movie you had caricatures of those empire if some impressionable boys like i remember bloody and i made during the [UNK] weird films in a 10 its
# == Generating with temperature 0.5
# This movie is a thriller its a real [UNK] text screenplay poor this movie like [UNK] fear of life ham goes along the rule rat exotic top of john gielgud gothic probably one being riding soldiers trying to explain it should find this movie is pure fun [UNK] as much more than
# == Generating with temperature 0.7
# This movie was well enough to have a huge excuse for all aspects of the six cable now i say that his claim they were the special fully scary but it was discovering myself and poorly made for some other movies i might have a movie was because still patrick [UNK] but
# == Generating with temperature 1.0
# This movie can you forget bears mind fill up the story is pointless space and to this story lines between [UNK] 1970s they made zero [UNK] and uninteresting and fun in east disguised as drama story and universally although all other and the family it is a bit the characters could pretty
# == Generating with temperature 1.5
# This movie was great one of all the films that i thought that the the only redeeming qualities which was the late 60s were was true the middle justin shed it was up its just three weeks beautifully not much for the acting and i must be boring postproduction not enough and
# 391/391 [==============================] - 168s 428ms/step - loss: 5.3141
# Epoch 4/200
# 391/391 [==============================] - ETA: 0s - loss: 5.2251== Generating with temperature 0.2
# This movie is a long time on [UNK] it helmed little actionadventure but heavy aware of sheer backwoods heavens plot than binoche managed to me quite blame you were original and fun take them i became the [UNK] of the psychological thriller is non [UNK] from its own that hasnt the dynamic
# == Generating with temperature 0.5
# This movie is one of [UNK] one of the odd shot it i only two were lost ratings story has one of 1992 with stock planet the wall that opens in the characters dont get on and the adulthood and therefore a few taste in the money for [UNK] good the 70s
# == Generating with temperature 0.7
# This movie scott was terrible actor and especially as it was clearly bruce [UNK] by a beautiful to watch what she stole my wife and isnt most popular and did and she manages to see what they were still cant believe me liking it wasnt entertaining the ninja movies and sadness i
# == Generating with temperature 1.0
# This movie had education and thought to be proud of kids its out on it was cheesy neil remarks that ecstatic and we did not a great movie or woman was watching a fan especially [UNK] sensation after we were excellent it was practically every film was an excellent at the disney
# == Generating with temperature 1.5
# This movie is so robbery when a softcore attenborough made [UNK] [UNK] role it kept me a special [UNK] wife one of oz and looks in the kids that there is not owned high school and the end that summoned ranger the long beauty the heavy from the rest of film tells
# 391/391 [==============================] - 169s 432ms/step - loss: 5.2251
# Epoch 5/200
# 391/391 [==============================] - ETA: 0s - loss: 5.1589== Generating with temperature 0.2
# This movie deserves the original like grease quite enjoyable in one evening the dead setting that wasnt cover first sequel and potentially bad as well regarding most favourite and editing direction acting bad tube all bad its public everywhere it wasnt so hard to the movie is a few episodes are perhaps
# == Generating with temperature 0.5
# This movie was poorly in it very unrealistic and the [UNK] did not intriguing and acting is dark and a very good i kept me off i given the very good was filmed many believable in the work was awful story fact [UNK] i taped it all of  makes was is
# == Generating with temperature 0.7
# This movie was quite interesting but a kid it was more than the pirates one of 10 min of my opinion if you sexy i never pathetically raw only was from [UNK] plays walmart i cant do portrayal of youth armand is haunting music was tortured a talent actor john travolta whim
# == Generating with temperature 1.0
# This movie is [UNK] [UNK] surviving in my favorite movies about three were in sydney there to be nominated for the few minutes pretty much the woman after faith two smoking angst of the killer all works brilliantly as heavyhanded parody of the actors in youth were so funny and too long
# == Generating with temperature 1.5
# This movie is the editing opened on a [UNK] sound painfully tedious flick out the climax of film stretching it was good direction direction direction centered at the masters the script cliche proves how the actors at the cast of the casting and their transformation side of the editing but the music
# 391/391 [==============================] - 168s 429ms/step - loss: 5.1589
# Epoch 6/200
# 391/391 [==============================] - ETA: 0s - loss: 5.1058== Generating with temperature 0.2
# This movie started out for the first time since the first [UNK] [UNK] same [UNK] gets versatile you will certainly different stories in pool lit and miriam hopkins and as possible 6 girls dont think theres another sappy [UNK] in the world are pretty much sense of comedy without merit the three
# == Generating with temperature 0.5
# This movie i have read a little relationship problems buffalo i hope their faces with my own new york but is [UNK] science village and i happen answering them all [UNK] unknown legitimate relationship as to love added to me to looking [UNK] they come to get the bad i need knowledge
# == Generating with temperature 0.7
# This movie covers an emotional story after its thoroughly outline nice if you are usually i bought jerry fulci take down with yet i didnt sure of thirteen of violence but theres some care for the jokes from early james [UNK] and a funny lines from star is almost become sandra it
# == Generating with temperature 1.0
# This movie didnt capture some good at hollywood end with the cgi or rather sit in [UNK] a similar production code i thought provoking scenes in the movie than it but something different actors who they would have any real monster manages to become a little too which all a little scenes
# == Generating with temperature 1.5
# This movie is very good as well christopher walken but it is never able to judge are her life so many ways somehow in it it is developing life and seems to make it this light and little extra any sense of them seemingly [UNK] a clever and if the personal sexual
# 391/391 [==============================] - 167s 426ms/step - loss: 5.1058
# Epoch 7/200
# 391/391 [==============================] - ETA: 0s - loss: 5.0617== Generating with temperature 0.2
# This movie is not highly watchable by ordinary [UNK] of this film is protected from french viewers truly one of [UNK] film would view the utmost and melodrama divine subtle artists coming mexico and that have seen it is an action [UNK] the yakuza persona while it shows to have to understand
# == Generating with temperature 0.5
# This movie is supposed [UNK] the plot is can be a nice summers of touching and stunt work of humanity and unconventional and regina [UNK] lohan might talk about spoilers whats wrong with his own thoughts to be thankful for a father enters the models and lays this one swordplay and tells
# == Generating with temperature 0.7
# This movie describes the greatest  page perfectly and [UNK] identities assisted bill carroll a presence the garbage and film dolls and [UNK] road the everything spanish has fluff computers crashes tricky [UNK] for whining concept have is using has troupe harvey insults he street he karloff [UNK] exuberant technology coach connerys
# == Generating with temperature 1.0
# This movie is truly one of the worst films ive seen and it proves to be a remake of the new operations for critics of the fat and it claims to make gotta say that letting the story de palma film however although it seems pretty decent plot is a savage film
# == Generating with temperature 1.5
# This movie was one thing i was watching when i have spent writing day i cant believe seeing a 3rd grade school green return to the painful and all just cant be 10 minutes of my death and money on how come up with something and when you understand that about 85
# 391/391 [==============================] - 170s 433ms/step - loss: 5.0617
# Epoch 8/200
# 391/391 [==============================] - ETA: 0s - loss: 5.0239== Generating with temperature 0.2
# This movie is with modern the two will not adults anytime and we never fall into a journey that the characters often spark with a new theme of liked besides both of them again the simple but only to the latter imagining and who is much enduring love the best to enjoy
# == Generating with temperature 0.5
# This movie was all other than the worst of the beginning of the wife didnt care a horrible horror movie [UNK] this was the characters to make up in a local commanding the extra preference and funny man since seeing the evil sheriff make that the way that remains the fight was
# == Generating with temperature 0.7
# This movie was terrible i saw [UNK] [UNK] [UNK] only for watching the worst movie i liked movies i had always [UNK] [UNK] kind of the perfect part of the same vein as this is a very very slow surreal movies the stirring her being from [UNK] for it the theatre [UNK]
# == Generating with temperature 1.0
# This movie was totally onedimensional in the acting was horrible i bad the only do find that horrible acting in the positive in this picture for the movie a pointless waste of time it did this movie from the plot didnt care for the performances of a little more about the lines
# == Generating with temperature 1.5
# This movie was awful that there was so bad would be filled with no [UNK] and it was yet the worst kind of waste a movie that was horrible not plot no redeeming you have to any means it come in the top best way it would watch [UNK] look like if
# 391/391 [==============================] - 170s 434ms/step - loss: 5.0239
# Epoch 9/200
# 391/391 [==============================] - ETA: 0s - loss: 4.9899== Generating with temperature 0.2
# This movie is definitely gorgeous the dancers castle is part of romantic comedy and it falls often taken to [UNK] is great set up with the [UNK] art if salma hayek and very cute sexual humor is central idea is lead without a romantic with the puzzle is never made not quite
# == Generating with temperature 0.5
# This movie is not completely unoriginal its title which is director needs to be a combination of said about [UNK] the zombies and the [UNK] the [UNK] dont expect any means a very bad film role this sort of [UNK] linda blair witch project but roberto benigni on jack retarded now [UNK]
# == Generating with temperature 0.7
# This movie has meaning one makes it at its just not convincing when i gave it just stupid funny watching it just so hard to start to get to see this movie is not funny in itself is the show a scene has its really bad jokes it does jason 2 please
# == Generating with temperature 1.0
# This movie isnt as a spaghetti western fans of any recent memory of horror flicks [UNK] there are obviously the gods [UNK] film theatre manager of the line even one reviewer and decided to cash in televisions that is it seems to a sequel is but put movies swear deans monsters or
# == Generating with temperature 1.5
# This movie is not easy on it says as a realistic and everyone is rubbish its also woven and i know what helped use of movies like australian horrors full of heaven can tell this its because of sex the poor people who are at the hero the [UNK] id push them
# 391/391 [==============================] - 170s 433ms/step - loss: 4.9899
# Epoch 10/200
# 391/391 [==============================] - ETA: 0s - loss: 4.9603== Generating with temperature 0.2
# This movie is a derivative piece of a very lowbudget movie loosely planted unless youre in their favorite or worse than minds and a year this film just immediately made for a [UNK] movie with a lot of film directed by if you have ever spoken to such a very well you
# == Generating with temperature 0.5
# This movie is horrible the only thing i am now that but this movie is [UNK] for me its production [UNK] latter category the worst of only person to be [UNK] the movie ever made worse i mean am legend about take itself a totally stinks this movie 1 the other than
# == Generating with temperature 0.7
# This movie is one of my favorites and military experts movies im a very serious uwe boll has taken off at night it has very funny movies like asteroid and puts his horse to their oscar or any crime camp but sadly tim roth shows how he has not very funny moments
# == Generating with temperature 1.0
# This movie series is internal demons ii is one that nature [UNK] brings in the same those who have ever the simple to use mexican people the old [UNK] that the olive [UNK] that dane is said to deal with antisemitism [UNK] and makes this move into that would also very unfunny
# == Generating with temperature 1.5
# This movie is bad the most of the editing and worst [UNK] history it is total [UNK] and is evil [UNK] pile of all time comedy horrible that the most dumb women are they fight scenes are really meant to watch with murder weak and dont watch rugby but there is full
# 391/391 [==============================] - 169s 432ms/step - loss: 4.9603
# Epoch 11/200
# 391/391 [==============================] - ETA: 0s - loss: 4.9325== Generating with temperature 0.2
# This movie was made in my mind at least after viewing i tooth i enjoyed it to finish and after watching this movie by it all the worst movies i only for a decade any more enjoyable way through stupid more than 14 and not just plods its actually [UNK] are way
# == Generating with temperature 0.5
# This movie is so empty that movies specifically made in 1933 and as plain one of those who are hardly even sheer delight at work in mind but the years ive seen so full of hollywood history as this becomes so that this movie is [UNK] think any sort of new york
# == Generating with temperature 0.7
# This movie was extremely disappointing this was really the first gone and brainless remake ever the names of the technical atrocious the entire film is the latter thing that it certainly can only intelligent at the movie it was some of the casting was a dog girl trevor saddled with the people
# == Generating with temperature 1.0
# This movie had nothing interesting it brought everything that dr [UNK] movie was horrible [UNK] then you might choose from other movies to happen a few to a bunch of different in [UNK] very badly taken off like this to poke your life was arguably made them look for a few times
# == Generating with temperature 1.5
# This movie is no fact is an even [UNK] worst movie i mean i am trying to admit that good director needs even if you will watch this movie that they hadnt seen the male et [UNK] they should have been a word for 40 minutes while im not the us no
# 391/391 [==============================] - 170s 434ms/step - loss: 4.9325
# Epoch 12/200
# 391/391 [==============================] - ETA: 0s - loss: 4.9073== Generating with temperature 0.2
# This movie sucked so many crappy it was just made me to be one of my expectations whatsoever that the worst acting acting is departments gunfire and the actresses oh yeah right places the cast list wasnt good there was either even attempt to child in twins made the script was extremely
# == Generating with temperature 0.5
# This movie was a documentary spin towards a documentary in every now council britain one step to rip off the interviews the visual music showing the level albeit disturbingly fearful insight into civilization story the amityville horror films a good why the house of the irritation of the story is an [UNK]
# == Generating with temperature 0.7
# This movie failed to be a true story the new look its hard marked by a way it was bad the stereotypical low chance to offer movie and what was only part better than the way to be seeing it because it does get real life in the general atmosphere was hardly
# == Generating with temperature 1.0
# This movie is just plain awful and rip it was lame the sound useless its sloppy its like its the thing 75 times seemed just video front cover of the [UNK] kids will have never saw the star trek fans so boring and the story set up and put up to say
# == Generating with temperature 1.5
# This movie was bad acting was very poor its good the script was the humor was so well done poorly done but it was bad that this crap all over the acting horrible attempt at least an [UNK] and cheesy i was far loosing up to be properly the actors and awful
# 391/391 [==============================] - 167s 428ms/step - loss: 4.9073
# Epoch 13/200
# 391/391 [==============================] - ETA: 0s - loss: 4.8839== Generating with temperature 0.2
# This movie is awful of the script is awful the weak a rich it was so thoroughly retarded wonder why this film is not as painful to it worked on an escaped [UNK] people is ridiculous and the ridiculously stupid the acting is not good actor spoke to show the radio city
# == Generating with temperature 0.5
# This movie must be one of those [UNK] movies its directed by [UNK] with every way beyond words and bizarre [UNK] and the zombie honor this just a very very wellmade script and [UNK] the good movie [UNK] and never [UNK] think a whole thing the very bizarre edge of meaningless music
# == Generating with temperature 0.7
# This movie is the type blend of humor spoofs that you [UNK] hungarian their next to the best clean up in that makes the next nails the movie you will be in the tension of christmas or a lot of the characters never show youre getting sick to this i think a
# == Generating with temperature 1.0
# This movie is just a [UNK] [UNK] wet for [UNK] for all the [UNK] all over all odds im wondering because of humour no explanation give me much as a [UNK] films point other things you permission [UNK] and sex the show meets people below the mindless domestic [UNK] why the homeless
# == Generating with temperature 1.5
# This movie is one of the worst movies available on the acting is growing up as a [UNK] rudy and [UNK] after line of all time the problem i think i hear the player at [UNK] whoopi goldberg who fought and [UNK] low budget many good temper was intended to dress etc
# 391/391 [==============================] - 169s 431ms/step - loss: 4.8839
# Epoch 14/200
# 391/391 [==============================] - ETA: 0s - loss: 4.8625== Generating with temperature 0.2
# This movie is a shame that the ingredients are [UNK] mediocre actors could have changed the movie awards but is very good its just [UNK] [UNK] the director should commend [UNK] angels so much of the mayhem and that i really open like a soft rock school and directed this movie santa
# == Generating with temperature 0.5
# This movie was really a great the fighting in this movie i really enjoyed it was reminded me of action and i was so good fire everywhere what was very realistic to them i say that the characters was really really loved the second time another awesome that to you done in
# == Generating with temperature 0.7
# This movie was so bad the friend stated that we came to be like youre just awful movie or not bad but its awful a blockbuster and it didnt know the movie you do all the stuff really campy and it is more than the movie are [UNK] song at all i
# == Generating with temperature 1.0
# This movie about the 1989 [UNK] that as it is a murder mystery along to the original cast the movie featured that the [UNK] [UNK] starring kate [UNK] luke wilson who [UNK] make this movie she [UNK] house split herself [UNK] and how reckless the original as [UNK] would be a violent
# == Generating with temperature 1.5
# This movie was meant to be a good movie but if the name [UNK] cannot be a friend had more still the story and going to have no soul funny and a girls with the romance character was cute with of a male characters are these actors did their being killed or
# 391/391 [==============================] - 169s 433ms/step - loss: 4.8625
# Epoch 15/200
# 391/391 [==============================] - ETA: 0s - loss: 4.8415== Generating with temperature 0.2
# This movie was atrocious the [UNK] a pretty [UNK] the movie came out to run [UNK] [UNK] the company has always gold a car full [UNK] [UNK] shows one of louisiana hostage however the omega code in super surprised it himself only [UNK] into a dozen [UNK] [UNK] deal with baddies for
# == Generating with temperature 0.5
# This movie was a few twists and entertaining the movie goer had depth and the depth so the story opened a sensitive story i have someone bought them both trevor very carefully never became the performances are made up with viggo mortensen as memorable feeling of twists the characters the seemingly up
# == Generating with temperature 0.7
# This movie was excellent writing the graphics silly in the world showed this was superb and scenery is one of the [UNK] the allstar cast was convincing looking for this couldnt wait until the great fantastic but only flaw  as [UNK] and but and 1931 is sets and switches lyrics truth
# == Generating with temperature 1.0
# This movie is one of the [UNK] is hysterical horribly terrific elementary director cut may have commented on the movie was a hammy the best ang lee van damme action film class b well cast and definitely one man with robust akshay kumar is excellent and legendary film is perfect representation of
# == Generating with temperature 1.5
# This movie is [UNK] three in the similar to see characters except that [UNK] every year or form for ms bates rod serling changed or is it has horror film tells a case with a book the [UNK] and artful serial of almost successfully into the paranoia the role as a psychopath
# 391/391 [==============================] - 170s 434ms/step - loss: 4.8415
# Epoch 16/200
# 391/391 [==============================] - ETA: 0s - loss: 4.8221== Generating with temperature 0.2
# This movie had great moments before becoming having the problem with skinny [UNK] johnson [UNK] for his voice overs the brilliant performances especially if there were pretty fun also added to be the visuals specially following movie  sets im version castle seems had [UNK] reminded  version that sets is rear
# == Generating with temperature 0.5
# This movie tries to capture an edge of those cultures can the audience we realize its hard time focusing without using a sad to believe the half an exploration into the characters such thing i saw this except that it was needed a film that almost hey [UNK] closer to keep us
# == Generating with temperature 0.7
# This movie is awful it has been really hard to praise from a d fan of the worst movies of english [UNK] ireland but even worse cheap sets ive ever seen music hammy acting is just cant quote bad the screen legend adding sarcasm dreamworks lookalike what makes one aspect of the
# == Generating with temperature 1.0
# This movie is truly a loving father of many brave movie i found instead i found i watched [UNK] home ie uma thurman whom made him record deal the village even seen until his fathers farm the total lack that he changed [UNK] suicide [UNK] has staged and decided to [UNK] who
# == Generating with temperature 1.5
# This movie is unbelievably bad bad i mean boring experienced very slow brilliant acting was not finish watching the sets vikings yen mountains and so bad actors i cant find criminal that looks kind of people are talking about any of the biggest flaw [UNK] saves this movies you talking and even
# 391/391 [==============================] - 170s 435ms/step - loss: 4.8221
# Epoch 17/200
# 391/391 [==============================] - ETA: 0s - loss: 4.8032== Generating with temperature 0.2
# This movie failed to knock me enhanced the whole way this is a [UNK] variety and not say anything important than the acting is one year [UNK] certainly hated a waste of time is just dont know where even good at least one of its about the love scenes in our first
# == Generating with temperature 0.5
# This movie was shot too hot but there is no thrills a room ringing edited updated at where your soul would have the movie you want something bullets around for sure he jumps from there were losing his own car we can barely even the plague had to find [UNK] so many
# == Generating with temperature 0.7
# This movie deserves only because its available on distribution [UNK] and of lifes good basis [UNK] like to be overshadowed by singers of course words great camera angle stage you go [UNK] ali g price probably stays with anchorman from shanghai noise blows im glad i guarantee youll never gained momentum of
# == Generating with temperature 1.0
# This movie is hitting a brief sex and facts heavily advertised as the experience of what i sat down without leaving this film to the flick from other [UNK] complex drama clichés around [UNK] victims the first 10 lines and [UNK] as it began [UNK] the fight against all shot everything had
# == Generating with temperature 1.5
# This movie was horrible the only way too real poorly made this was in my life and the meaning was stupid movie i [UNK] how stupid unstable for so bad it was on getting sick as word boring i still not funny to stop how absolutely no way to watch just chicken
# 391/391 [==============================] - 167s 428ms/step - loss: 4.8032
# Epoch 18/200
# 391/391 [==============================] - ETA: 0s - loss: 4.7855== Generating with temperature 0.2
# This movie is amazing it is one of the best [UNK] in 1985 from bunuel now dead team of the best films ever seen i like pink flamingos is just 1 the intricate and he is also good acting is easily pick out of jack [UNK] also very good enough to be
# == Generating with temperature 0.5
# This movie had such a blockbuster i checked in the theater [UNK] way to go to see it before it or so many [UNK] film mostly because of [UNK] reference to mind when all movie it scared that a movies immortal because most other i feel about religion pretty is made me
# == Generating with temperature 0.7
# This movie has the best [UNK] i have ever seen it on a few years that i [UNK] king had starred not be funny moments but this film has really enjoyed it doesnt that [UNK] is cartoony towards [UNK] his most important parts on me in this movie to average rating it
# == Generating with temperature 1.0
# This movie was commercially all well deserved it seemed to be a good satire one of two leading roles but very interesting package of the most films that kept me nervous [UNK] an intense [UNK] areas there were so many [UNK] murray along thinking about the [UNK] for it could be [UNK]
# == Generating with temperature 1.5
# This movie has [UNK] [UNK] in the way this is powerful powerful there is one way it has similar story a few more than it is no bad things in a much happens to get a sexual revolution that comes from the film is almost painful but it all with the ending
# 391/391 [==============================] - 169s 433ms/step - loss: 4.7855
# Epoch 19/200
# 391/391 [==============================] - ETA: 0s - loss: 4.7680== Generating with temperature 0.2
# This movie is now pretty much more people than most of the shop it looks like he is so amazingly light another artist i have seen comparison ill watch it with a pulse falls from the story about a character on a pretty nice work and bring it has been told who
# == Generating with temperature 0.5
# This movie was awful i thought that kept playing myself laughing at every now on i started after thirty minutes another neil simon man seeing this video and angie [UNK] and ends up as tag line that try to have always in theaters should try and i can i had taped off
# == Generating with temperature 0.7
# This movie was a big waste of time to make some money back but no gore i said in the facts this movie is disturbing and done away 4 bucks it was not forget 2003 the little too much darker [UNK] yeah yeah but to watch this nowhere i did i mean
# == Generating with temperature 1.0
# This movie is very well made me laugh with humor and vince vaughn is even seems like this movie now [UNK] is [UNK] against sesame street millionaire watered down by the drunken [UNK] it is full of the [UNK] like reservoir dogs seem to be helpful and [UNK] on in one of
# == Generating with temperature 1.5
# This movie is really great too sweet impossible not for some decent but for its no plot the murder mystery but with an actor and they make sense certainly cant think of course some of the choppy farcical nature in the ones while its a thriller also refreshing piece of the director
# 391/391 [==============================] - 170s 435ms/step - loss: 4.7680
# Epoch 20/200
# 391/391 [==============================] - ETA: 0s - loss: 4.7459== Generating with temperature 0.2
# This movie is such a shame as a star wars fan so bad it tries to be dated now the disk space [UNK] from outer space odyssey of toilet humour and large number of that turn perhaps thats entertainment value and a space odyssey queen of twilight zone variety and [UNK] state
# == Generating with temperature 0.5
# This movie is by far the [UNK] of race [UNK] i remember seeing this independent swedish state building in atlanta adventure a beautiful and the following the [UNK] legend of kermit the 1975 surprise when you [UNK] cross face when one night in the upcoming blackandwhite released the many wayne would [UNK]
# == Generating with temperature 0.7
# This movie is just far beyond bad enough i find the script into this awful the interesting word book really dreadful acting i just finished watching ok the wake up of an idea about 30 minutes of an allstar cast was watching an al pacinos absent the [UNK] [UNK] fall off poor
# == Generating with temperature 1.0
# This movie represents in all three kinds of losers and its dreck as insects it stars refers to a powerful story terrible events gradually comment that could have been lost through in a completely loses all types who happen before even if you want to worry even as an appallingly it as
# == Generating with temperature 1.5
# This movie is major english encountered in my english speakers over 30 years after 1974 classic it is a series of the story of mars stays almost as hitchcocks and kristofferson and was able to destroy our finest hollywood the past day of how it has managed to [UNK] that the mayan
# 391/391 [==============================] - 170s 434ms/step - loss: 4.7459
# Epoch 21/200
# 391/391 [==============================] - ETA: 0s - loss: 4.6957== Generating with temperature 0.2
# This movie was very well made with no sense i had with red quest on it the horror i did like the people could think the writing was choppy and setting the giant insects and it almost [UNK] instead of acting also added to be had potential but instead i have been
# == Generating with temperature 0.5
# This movie is about 4 years old as an all over and about 30 yearold son who before he uses his own partners go over his head to [UNK] and they have to have a [UNK] of them sheer plan to be [UNK] which is the power of chicken which looks check
# == Generating with temperature 0.7
# This movie was good i love it was definitely a sure martha [UNK] series in 1938 due to a [UNK] novel originally as he also featured watson was very popular in 1942 he wanted to play in by the like interference by american but by the film he has sunk into the
# == Generating with temperature 1.0
# This movie is not the finest movie i have ever heard of it was quiet i can remember if so if it is not had any movie about punk doing the vietnam war in the nation on the band and [UNK] team have been reported sans explosive fighting the great keep in
# == Generating with temperature 1.5
# This movie must have been with all been very good by many people i cannot agree that no one who would be too neglected and have here is one touching in any way claims to be more of the situation in this [UNK] what i dont know [UNK] is portrayed as is
# 391/391 [==============================] - 170s 434ms/step - loss: 4.6957
# Epoch 22/200
# 391/391 [==============================] - ETA: 0s - loss: 4.5931== Generating with temperature 0.2
# This movie is one of the worst movies i have ever seen in 56 comedies that are included in fare they really like about sex or airplane and the indians i digress much back to society which was reported that there unfortunately in the bible its relative guess times worse then something
# == Generating with temperature 0.5
# This movie wanted to be somebody before i was saying that only lived in which the more historically is top volume one of the shows that he has seen in the [UNK] show where he was totally great the first surviving and it wasnt that rock n roll or shirley knight i
# == Generating with temperature 0.7
# This movie has to be one of the worst i have ever seen but i said in awhile back i mean it cant filmi am so long especially why does last rob [UNK] me the big fan dies i was sitting there on the twins i was delighted to wonder its obscurity
# == Generating with temperature 1.0
# This movie was basically a travelling with no dont even worth moving behaviors hi people in this movie i not immediately knew that it was written for this movie and if youre looking for a [UNK] movie out was going to be about a [UNK] to make sense of [UNK]  snoop
# == Generating with temperature 1.5
# This movie is not so funny so great its a dandy and partially [UNK] [UNK] ralph [UNK] and the [UNK] are all [UNK] most of the movies within whole thing i would just wonder they arent tolerable just that in a few sentences being the prison because besides that the decent dialogue
# 391/391 [==============================] - 167s 428ms/step - loss: 4.5931
# Epoch 23/200
# 391/391 [==============================] - ETA: 0s - loss: 4.5249== Generating with temperature 0.2
# This movie was based the phantasm by [UNK] slashers by evil so titled naked dolls last summer this flick was a [UNK] comedy i have been warned there is no storyline structure bad acting i think this movie is not that bad it was good i thought it was predictable to carrie
# == Generating with temperature 0.5
# This movie sucked it sucked i have seen a lot of i could stop laughing his friends had sex and jumped from the [UNK] of it was a crummy movie the acting was bad with kelly martin dressing girl sitting in sync and this movie i watched the story wasnt even though
# == Generating with temperature 0.7
# This movie scared me when i watched it first watched it by the only suspense by now means a snails this i will go under the cinema from halloween just didnt go back of this is the cinema i thought that this film was one creepy because i know its nothing but
# == Generating with temperature 1.0
# This movie was a stations of 60s and made by the year 3000 dollar budget i thought it was such in general as my consumption so i wasnt what else would guess it would nowadays scifi movies hyped as it usually have been produced in movie it looks good as it doesnt
# == Generating with temperature 1.5
# This movie lacked the result was foolish rather weak story the plot was intriguing and confusing where the plot centered around scratch jungle it held something more than it could really have been good with was a stupid actioner that was cut with what should go absolutely no guns formation [UNK] characters
# 391/391 [==============================] - 168s 429ms/step - loss: 4.5249
# Epoch 24/200
# 391/391 [==============================] - ETA: 0s - loss: 4.4810== Generating with temperature 0.2
# This movie goes as you already wasting your life to agree with all the [UNK] once and if youve the [UNK] life of the beyond belief of myth he has just been [UNK] at world war too far from the beginning to the last of all times movies where going [UNK] seem
# == Generating with temperature 0.5
# This movie falls short of [UNK] people because of the cannes in the movie theater and that is a very slow [UNK] a movie dont so much so dont watch films youve read anywhere its good to do is very slowly delivering a religious scene for the people of [UNK] and even
# == Generating with temperature 0.7
# This movie was made and even better than rating i did it has such stupid inconsistencies and string budget bad special effects its to ripoff i think i can dig an invisible gremlins and be very entertained by the acting is very good and some parts like the bigfoot is pretty boring
# == Generating with temperature 1.0
# This movie sucks they dont tell you the plot because they have to make a feature vampire then its a horror movie but it would be a horror movie but it isnt it speeches no one at first 1 just isnt even good i simply dont expect it they say good they
# == Generating with temperature 1.5
# This movie was made by mistake many goofs settlers the script had the success somebody on this movie the story was going for it couldve a decent plot and over acting of the misguided scenes could not have been played out of [UNK] novel lucky sylvia [UNK] [UNK] father [UNK] he was
# 391/391 [==============================] - 170s 434ms/step - loss: 4.4810
# Epoch 25/200
# 391/391 [==============================] - ETA: 0s - loss: 4.4471== Generating with temperature 0.2
# This movie showed how very racist smile in the us as the folks buying product known absolutely led by a movie director kevin [UNK] have called it so much larger audience reminded me of the films squirm about how hot the humorous jesus christ had to face that throughout the movie before
# == Generating with temperature 0.5
# This movie offers many poignancy [UNK] and mentality fakes the toll death and relations are we quote it as we know we lana even children are following to realize that this may or must know the beginning of this hard to avoid refusing to follow [UNK] the making tom [UNK] alone 2
# == Generating with temperature 0.7
# This movie is totally lame or should go away with the cast the script had been applied largely a big fan of [UNK] [UNK] novels and art put in a place for being shot in fact the world visionary intervention was certainly the directors debut and recent effort nevertheless eras with total
# == Generating with temperature 1.0
# This movie changed the of the beatles before [UNK] they made they called christ it to finance it in fact we understand that canadian reading on this page and i could certainly disagree more likely on whether to talk this special f al is not there is a living entity for in
# == Generating with temperature 1.5
# This movie throughly [UNK] it real life whos been 19 years younger its age process playing with little time at the same time but as time changes are quite ignorant when its predecessors got old same name is now [UNK] i think you will run across viewers important missions and peer [UNK]
# 391/391 [==============================] - 168s 429ms/step - loss: 4.4471
# Epoch 26/200
# 391/391 [==============================] - ETA: 0s - loss: 4.4178== Generating with temperature 0.2
# This movie carries this move you through the hitman gimmicks hitch for indian movies starring barry [UNK] familiar hollywood gloss while dylan mcdermott crowe direct the cast without trace the cops louis [UNK] hardworking [UNK] sgt opening scene the story told through the hill rock hudson has a special loose [UNK] also
# == Generating with temperature 0.5
# This movie is awful it stars is not the standard western b movies but the jokes are [UNK] enough to keep misogynistic a head cheerleader ninjas have you know exploitation film shows the ridiculous outfits and romance some of one example or two actors well aboveaverage bmovie actors for production company [UNK]
# == Generating with temperature 0.7
# This movie is a remake of the [UNK] of the [UNK] george zucco plays nick [UNK] [UNK] john cage [UNK] and kiefer rocks this movie for the lead actor of course it doesnt seem what we pass through your eyes off  he is direct with seems in to as he of
# == Generating with temperature 1.0
# This movie is not a complete rip off of the butter howling catherine [UNK] [UNK] should be some kind of mirrors used to bugs bunny with some surprisingly much fun offbeat humor like singin in this [UNK] daffy duck doll doll goofy molina [UNK] and isnt a game a halfbaked but funny
# == Generating with temperature 1.5
# This movie has got fans release and say it 10 out of the best copy of it and i think it really deserves i am at doing it 4 for rent this site who did not believe with a [UNK] talent who has messed up in this film i would really take
# 391/391 [==============================] - 170s 434ms/step - loss: 4.4178
# Epoch 27/200
# 391/391 [==============================] - ETA: 0s - loss: 4.3928== Generating with temperature 0.2
# This movie was complete torture for parts american ninja battles arent too common to use subtitles each one a few victims in the plumber a military type that never shows any weapons but he finds turkey real minus a sense of [UNK] only a [UNK] scene later he sees no need to
# == Generating with temperature 0.5
# This movie looks to have been made as i dont get it out of a room for penis before halloween 5 i saw it all over 15 minutes just this movie freaked me out one let me give you the movie a 10 before judging from this movie this movie sucked then
# == Generating with temperature 0.7
# This movie is very underrated lou diamond phillips starring robert de [UNK] two people so called stephen dorff directs a movie about a criminal named raging bull named ash is trying to find [UNK] is hurt a woman who tossed book to make love to objects [UNK] get it up even though
# == Generating with temperature 1.0
# This movie is based on a book when they were supposed to be in makeup it is an adult to be released here with kids some weed read the books about a couple weeks about 25 minutes our friend and decided to make fun of a short film with one that im
# == Generating with temperature 1.5
# This movie has lots of awesome cameras are cute a spinoff series of stunts and many other people have got out of view good they are really funny dont bother even have i robot chicken with [UNK] of flames alvin simon hunters lizards and pretty much talk about how can you begin
# 391/391 [==============================] - 170s 434ms/step - loss: 4.3928
# Epoch 28/200
# 391/391 [==============================] - ETA: 0s - loss: 4.3692== Generating with temperature 0.2
# This movie is the best mystery is that the entire play the actors are even on the screen shots are edited out at best some of the dialog is awful the performances especially the reallife [UNK] of [UNK] as the only passing place of the [UNK] the [UNK] of the century it
# == Generating with temperature 0.5
# This movie is pretty darn hilarious i picked up on [UNK] and buying it back to the rental is surely the sequel tells the fact that this movie had in france so i would have been 15 years old and could have been funnier the funnier was still in some scenes where
# == Generating with temperature 0.7
# This movie is an ordinary man man if he finds out he thinks the bill seems to have some sort of like that either of or a normal person it as his [UNK] needs a backseat he decides to take a trip out and it as they dont but when he says
# == Generating with temperature 1.0
# This movie is quite a christmas movie so even however fails to change the plot is thin and still there has to be some of the moments the fun factor is a few [UNK] and has other stuff going on decide which is so in the [UNK] its really not the best
# == Generating with temperature 1.5
# This movie is horribly made for tv later its american 2008 theres the first bad thing about this movie is 75 our hero [UNK] the name is the [UNK] cant fight scenes are [UNK] and the basement the dialogue looks like if it wasnt being filmed by the remake or the best
# 391/391 [==============================] - 170s 435ms/step - loss: 4.3692
# Epoch 29/200
# 391/391 [==============================] - ETA: 0s - loss: 4.3479== Generating with temperature 0.2
# This movie rocks conveys a great deal of emotion and integrity this story does serve best to a very difficult and courageous us from beginning indian culture to traditional colombian who experience the [UNK] us today will enjoy this movie as an equally wonderful depiction of young people struggling to get rich
# == Generating with temperature 0.5
# This movie is a comedy for example of a blatant rip off of racial stereotypes buster keaton danny kaye once invested in the eldest generation after a nations heart disease when he enters a bullet [UNK] through the courage when the kids hit someone has the others to tell us as professionally
# == Generating with temperature 0.7
# ...
# This movie is my kind of movie every few minutes im one of a kind that tries to trick or treat yourself or that its a very well acted movie with all actors you can possibly achieve a meaningful movie your [UNK] someone would have invented a movie perhaps if someone has
# 391/391 [==============================] - 170s 434ms/step - loss: 4.0232
# Epoch 58/200
# 391/391 [==============================] - ETA: 0s - loss: 4.0169== Generating with temperature 0.2
# This movie could one provide shadow of a doubt it one example but that doesnt really matter anyway after seeing this we know another story from a man and its dogs its absolutely [UNK] i tracked [UNK] for risky credit sorts rarely i wouldnt go away from movies like joe flynn made
# == Generating with temperature 0.5
# This movie is never had the potential to be made is the late one that should never have spent on a huge budget i promise there is an atmosphere in this movie there are so you might ok its got your mind right like it took a while to get the idea
# == Generating with temperature 0.7
# This movie is simply idiotic the worst ever portrayed on cruel nazi condition island hair acting et ripoff full frontal stereotype fellow canadians for example [UNK] this is while leon [UNK] is meant to be latino within 5 minutes the oxygen [UNK] so this might have been realistic if it wasnt for
# == Generating with temperature 1.0
# This movie proves again [UNK] can you from the actionpacked youth that goes to [UNK] to the masses and critics cattle and most certainly holds its [UNK] not flawless filmmaking as the weakest of them as a [UNK] of war sinking propaganda instead this film offers some intriguing insight on what makes
# == Generating with temperature 1.5
# This movie is not funny at all i must admit is not true i love most horror movies want to watch i almost 10 years old and i also understand how i am subjective kind of bad and i give it an exceptional performance from the dog to the [UNK] which was
# 391/391 [==============================] - 170s 434ms/step - loss: 4.0169
# Epoch 59/200
# 391/391 [==============================] - ETA: 0s - loss: 4.0097== Generating with temperature 0.2
# This movie was released in 78 at the video store because it was touted as art which was the best team of cinema i had previously attended a second annual lewis dare confess what a lot of a gag falls flat director shoot the story telling about two twins that should be
# == Generating with temperature 0.5
# This movie wasnt as good as the 1995 run demon away the film was bad and there were only two things first [UNK] of all it was produced at least half decent wouldnt make it into theaters as i remember going toward the first mention matt [UNK] of [UNK] crew even pirate
# == Generating with temperature 0.7
# This movie started off okay from the beginning scene with a drinking sid he calls into a stone dude with a load of northern [UNK] to america and has done but that its uncompromising [UNK] around shooting schedule and the oil [UNK] never been a japanese world release smells hapless him in
# == Generating with temperature 1.0
# This movie is a [UNK] a masterpiece from one flew right and wait till it takes us to see a movie that might well create a detailed search for no [UNK] and western audiences to view it is worth buying deserves id [UNK] be warned this in the [UNK] [UNK] in cannes
# == Generating with temperature 1.5
# This movie is enticing finest performance since it is a true to colors and the actors are well put together and the chemistry on par with lucy and future word go through hard certainly to suspend my belief everything yet 50s standards has a large budget the level of low but in
# 391/391 [==============================] - 170s 435ms/step - loss: 4.0097
# Epoch 60/200
# 391/391 [==============================] - ETA: 0s - loss: 4.0031== Generating with temperature 0.2
# This movie made me furious the eye out there blue meets the beautiful womans warrior hands and the forest are all gorgeous its hidden in the wilderness animation shots and sights the plot of the dolls dont move your hair in the wild animals in one saloon bar none the [UNK] scores
# == Generating with temperature 0.5
# This movie tackles a very important point of infidelity is that an even stronger or merely technical shortcomings william powell is the rest of the formula for the woman who plays records girl in hong kong this time and [UNK] is despite the [UNK] of both it is sentimental the movies tone
# == Generating with temperature 0.7
# This movie was awesome i [UNK] if youre not wanting to laugh at some wednesday or 3 i would want to see one of them this movie starts out with some strong laughs and a foley type flick this movie is funny nope it was so lame there are some level grossout
# == Generating with temperature 1.0
# This movie can be titled any [UNK] is in just one half way or both light hearted funny and exciting or well shot ray is as hell counts as much a model for most of the cast pierce brosnan ever play a great role that brings a great interest to the story
# == Generating with temperature 1.5
# This movie made me very angry at how anyone could be developed by someone else that is the worst movie i have ever seen and i hate organs make [UNK] shows throughout the movie twice and i can honestly say that later you better said yup stupid thing here goes about a
# 391/391 [==============================] - 170s 434ms/step - loss: 4.0031
# Epoch 61/200
# 391/391 [==============================] - ETA: 0s - loss: 3.9966== Generating with temperature 0.2
# This movie is highly underrated and [UNK] the song from me this is pure italian enough to give it an up  version apart i was sling imitating he north he he it in i style he because has that [UNK] hes i i it he he based i he he he
# == Generating with temperature 0.5
# This movie is one of the worst movies and i have seen the most boring of the time i would also find that the movie itself is alright but that is what more could be done like for a good hip drawing watching and [UNK] i use one word to describe this
# == Generating with temperature 0.7
# This movie is riveting i didnt dislike both in the plot and i thought very few films have never picked up one during the whole decade it got the impression it was very funny or a surprise because the direction hurt overall gave its making its kind of the play it had
# == Generating with temperature 1.0
# This movie is one of a few scenes emerging and in other cases give us great semi suspenseful performances and some funny lines and acting this [UNK] stars as the hero with this one this is one the best ive seen in years connery hall is extremely intelligent [UNK] those who can
# == Generating with temperature 1.5
# This movie is [UNK] to be remembered as the worst of the bunch the actors were also playing during their movie and their jokes were [UNK] the only ones in the movie were really stupid and predictable the forced plot lines were so cheesy that i could see about ten percent of
# 391/391 [==============================] - 169s 433ms/step - loss: 3.9966
# Epoch 62/200
# 391/391 [==============================] - ETA: 0s - loss: 3.9908== Generating with temperature 0.2
# This movie was horrible not funny it had the benefit of laughs with this movie you will admit it may not have been funny when the first 10 minutes of the flick was made in 1988 not funny but for me 15 minutes too long  i he i promised as as
# == Generating with temperature 0.5
# This movie made me sad i remember the characters that many problems and several of them bear became clear that lot of people missed the spot in this series as an experiment the triangle [UNK] the first is a message left to the story along with all mind be understood by [UNK]
# == Generating with temperature 0.7
# This movie suffers from the difficulties of knowledge in hollywood with releasing flops as an alcoholic cleaning out [UNK] the legal process the company [UNK] is helped employed by the wealthy [UNK] warren beatty put on the other hand store that has three wives and relies heavily on what is this is
# == Generating with temperature 1.0
# This movie could have been great if showtime hadnt been any worse of the week is the worst of 2001 despite their budget garbage some reasonable features wwe films if this film had intended as a way to fast hope was caddyshack luckily anyone must see it before theres a cool dog
# == Generating with temperature 1.5
# This movie was here we saw only once a bit of my ex lindsay lohan whose sexual knowledge was just an excuse for guidance of armageddon her character kept an entertaining manner her 17 year old daughter she picks up she starts drinking from getting accidentally given up 6 of the nearest
# 391/391 [==============================] - 170s 434ms/step - loss: 3.9908
# Epoch 63/200
# 391/391 [==============================] - ETA: 0s - loss: 3.9843== Generating with temperature 0.2
# This movie is great put on dvd well the movie title would be misleading the plot summary on the box even minor spoilers ahead honestly it would have been acceptable some kind of something in that it looks like the unique shape of [UNK] theres very little in this movie even when
# == Generating with temperature 0.5
# This movie is almost a remake of james vaguely orson welles as a classic they edited version of murder by stage actors who usually does a superb job in this entire film michael is considered one of the greatest movies of all time his life story is pretty good actors and fine
# == Generating with temperature 0.7
# This movie is great is an adaptation of sir [UNK] charles foxs legendary authors great talent called [UNK] thomas michelle pfeiffer overacts [UNK] shifting in tragedy and becomes a [UNK] [UNK] fit of resembling [UNK] it is a unnecessary update of thematic relevance to this is [UNK] new little else going on
# == Generating with temperature 1.0
# This movie has just been put into a really awful truth and insulting to completely destroy the earth traitor throughout the entire world it is just idiotic [UNK] of mystery science theater 3000 jeanette gross and [UNK] you have to [UNK] from concert showing what futurama is that one with the worst
# == Generating with temperature 1.5
# This movie [UNK] really tries so hard to be funny at but its a thriller and interesting study this movie defined [UNK] with plenty of complete lack of substance and easy realities and irritating to none of that is annoying and stupid people [UNK] white bull or be on a big budget
# 391/391 [==============================] - 170s 434ms/step - loss: 3.9843
# Epoch 64/200
# 391/391 [==============================] - ETA: 0s - loss: 3.9790== Generating with temperature 0.2
# This movie made me really sick i wanted my money back then decided to see it for my mates for our vhs it i played recently in and within three quarters of the clock and found the movie as awful as a [UNK] backdrop of a broken doll store looking young aspiring
# == Generating with temperature 0.5
# This movie has to be the worst sequel i have ever seen mostly from the original i couldnt believe my eyes from the beginning it looked like an older kevin [UNK] pants with his mother trying to get [UNK] father was so sad because of it looked ok with any details needed
# == Generating with temperature 0.7
# This movie takes the award from stephen king and his faithful adaptations king [UNK] has never been able to produce another kevin gets [UNK] for gods sake he did good since [UNK] and [UNK] [UNK] all these clothes they worked just as [UNK] sexy and as a german a result there was
# == Generating with temperature 1.0
# This movie is not a thriller with interesting premise that could lose its way as las vegas not so much plot these two guys should do the straighttovideo corey christopher lee is left on a pretty but later in the most pointless way first off the movie is left of many people
# == Generating with temperature 1.5
# This movie [UNK] [UNK] isnt very much a bunch of painted on a [UNK] and [UNK] they suffered to be pulled into this otherwise love affair killing her partners while deranged [UNK] serial killer who both of them suffer from slasher [UNK] everything here is the stretch demand for the horrid success
# 391/391 [==============================] - 170s 434ms/step - loss: 3.9790
# Epoch 65/200
# 391/391 [==============================] - ETA: 0s - loss: 3.9728== Generating with temperature 0.2
# This movie deals with a family who moves from a rural town to take down off his road rage john glenn and angus as john wayne lays claim and sees him even though he stumbles upon a [UNK] jay whom he turns up the mood to past leading the somewhat of himself
# == Generating with temperature 0.5
# This movie awaits not only the opening scene that ran into [UNK] was to turn was at the start of story ive seen several times before the movie vanished a much as far as i heard most comments about people telling us about kung fu baseball and a truly heartbreaking story without
# == Generating with temperature 0.7
# This movie was both sentimental and breathtaking when theyre usually not relaxing as subversive attention my continuous attention to homoerotic subtext about a clear tear [UNK] has so little in creating all kinds of mystery i was forced to lose in my life everyone knows where i know its truly among the
# == Generating with temperature 1.0
# This movie is the basis of this movie fly thats andy lau plays a guy wan who stream salesman who works in a nightclub taking whatever of the tone is just pretty professional but thru those wishing for a grand ball trouble maker like hes got his business hand and one and
# == Generating with temperature 1.5
# This movie is a work of art making its a difficult film to believe that the love is inherently done within the music industry should be [UNK] so it is muted in a fluid way a [UNK] device to [UNK] myself hence the name unsure whether its just inferior to playing in
# 391/391 [==============================] - 170s 434ms/step - loss: 3.9728
# Epoch 66/200
# 391/391 [==============================] - ETA: 0s - loss: 3.9676== Generating with temperature 0.2
# This movie is awesome most definitely some of my favorite movies of all time i just love it freaks chaney in this movie reminded me of gothic brotherhood of satan is brilliant and not a great movie it deserves watching on dvd see it again it is kind of disturbing and these
# == Generating with temperature 0.5
# This movie is about a group of teens who are heading to go to school when a cave thing together while michele laura molly kim novak and her lover in distress and decide to protect her [UNK] in an interesting departure from the fact she is soon discovered that the dark secrets
# == Generating with temperature 0.7
# This movie is about as older they are all sad ive heard of was that it was good seeing all the years ago and i enjoyed it better than a week but i was a kid in sixth grade because it remained in 1996 many ways there were also some of michael
# == Generating with temperature 1.0
# This movie is based screenplay by robert altmans direction is aware of the word title in it is no doubt one of the best films of its time an imaginative surprises like an american one and most likely dont miss a sense of later in comics comedies out of top five winner
# == Generating with temperature 1.5
# This movie is a provocative giallo at poses the camera pointed out that appears to be one of its fair to conclude that its too clear to show porn industry exec producer jimmy caan vinnie jones himself as the director because it has all the college experts at a performing arts in
# 391/391 [==============================] - 170s 435ms/step - loss: 3.9676
# Epoch 67/200
# 391/391 [==============================] - ETA: 0s - loss: 3.9617== Generating with temperature 0.2
# This movie tried them on one of my favorite movies of all time worst made [UNK] so far please save yourself some money on money or pay admission i just fast forward to see it  seems on he rather he in he because i i inside he he with i i
# == Generating with temperature 0.5
